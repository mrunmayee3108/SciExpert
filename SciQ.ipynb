# %%
from datasets import load_dataset
import pandas as pd
import random

# %%
dataset = load_dataset("allenai/sciq", split = "train")
# Out:
# README.md:   0%|          | 0.00/7.02k [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/3.99M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/339k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/343k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/11679 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
df = pd.DataFrame(dataset)
print("Original rows:", len(df))
# Out:
# Original rows: 11679

# %%
df = df.drop_duplicates(subset=["question"])

# %%
len(df)  # 70 duplicate questions dropped.
# Out:
# 11609

# %%
df = df.dropna(subset=["question","correct_answer","distractor1","distractor2","distractor3"])

# %%
import re

# %%
def clean_text(text):
    text = str(text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()
for col in ["question","correct_answer","distractor1","distractor2","distractor3"]:
    df[col] = df[col].apply(clean_text)

# %%
df = df.sample(n=2000, random_state=42)
print("Final sampled rows:", len(df))
# Out:
# Final sampled rows: 2000

# %%
df.head()
# Out:
#                                                 question  ...                                            support
# 7325   When atoms gain or lose electrons, they can fo...  ...  In ordinary chemical reactions, the nucleus of...
# 10579  What control reproductive cycles, which are in...  ...
# 4885   Wich disorder arises when defective valves all...  ...  Edema may be accompanied by varicose veins, es...
# 4235   Because core electrons are closer to the nucle...  ...  Core electrons are the electrons that are clos...
# 3554   "endocrine" and "exocrine" are two types of what?  ...  The ductless endocrine glands are not to be co...
#
# [5 rows x 6 columns]

# %%
final_rows = []
for _, row in df.iterrows():
  options = [
      row['correct_answer'],
      row['distractor1'],
      row['distractor2'],
      row['distractor3']
  ]
  random.shuffle(options)
  answer_index = options.index(row["correct_answer"])
  answer_key = "ABCD"[answer_index]
  final_rows.append({
      "dataset_source": "SciQ",
      "text":f"Question: {row['question']}\n\n" f"A. {options[0]}\n" f"B. {options[1]}\n" f"C. {options[2]}\n" f"D. {options[3]}\n\n" f"Answer: {answer_key}",
      "answer_key": answer_key
  })
  clean_df = pd.DataFrame(final_rows)

# %%
clean_df.head()
# Out:
#   dataset_source                                               text answer_key
# 0           SciQ  Question: When atoms gain or lose electrons, t...          D
# 1           SciQ  Question: What control reproductive cycles, wh...          B
# 2           SciQ  Question: Wich disorder arises when defective ...          B
# 3           SciQ  Question: Because core electrons are closer to...          B
# 4           SciQ  Question: "endocrine" and "exocrine" are two t...          D

# %%
clean_df.to_csv("sciq_clean.csv",index=False)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   dataset_source  2000 non-null   object
#  1   text            2000 non-null   object
#  2   answer_key      2000 non-null   object
# dtypes: object(3)
# memory usage: 47.0+ KB

# %%
# ans distribution
import matplotlib.pyplot as plt
clean_df['answer_key'].value_counts().plot(kind='bar')
plt.xlabel('Answer Key')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - most of the answers are A, followed by C, B, D
# - roughly equal counts for A/B/C/D because of shuffling.

# %%
# ques length distribution
ques_len = clean_df['text'].str.len()
plt.hist(ques_len, bins=30)
plt.xlabel('Question Length')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - most of the ques are around 150 characters long.
# - very few questions are larger than 350 characters.

# %%
ques_len.describe()
# Out:
# count    2000.000000
# mean      156.489000
# std        36.440291
# min        71.000000
# 25%       131.000000
# 50%       152.000000
# 75%       175.000000
# max       420.000000
# Name: text, dtype: float64
